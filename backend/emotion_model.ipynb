# %%
# %pip install tensorflow 
# %pip install tf2onnx
# Out:
# ...
#   Using cached absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# ...
#   Using cached gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# ...
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# ...
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached grpcio-1.78.0-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# ...
#   Using cached keras-3.13.2-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached h5py-3.14.0-cp312-cp312-win_amd64.whl.metadata (2.7 kB)
# ...
#   Using cached ml_dtypes-0.5.4-cp312-cp312-win_amd64.whl.metadata (9.2 kB)
# ...
#   Using cached wheel-0.46.3-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# ...

# %%
import tensorflow as tf

# Load your existing model
model = tf.keras.models.load_model("emotion_model.hdf5")

# Convert to TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the version for your Raspberry Pi
with open("emotion_model.tflite", "wb") as f:
    f.write(tflite_model)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 import tensorflow as tf
#       3 # Load your existing model
# ----> 4 model = tf.keras.models.load_model("emotion_model.hdf5")
#       6 # Convert to TFLite
#       7 converter = tf.lite.TFLiteConverter.from_keras_model(model)
#
# File c:\Users\nguye\OneDrive\Desktop\uni\Y2_Sem3\jupyter\practice_vscode\my_virtual_env\Lib\site-packages\keras\src\saving\saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath,
# ...

# %%
import tensorflow as tf
import tf2onnx

# Load your H5 model
model = tf.keras.models.load_model("emotion_model.hdf5")

# Convert to ONNX
spec = (tf.TensorSpec((None, 48, 48, 1), tf.float32, name="input"),)
output_path = "emotion_model.onnx"

model_proto, _ = tf2onnx.convert.from_keras(model, input_signature=spec, opset=13, output_path=output_path)
print("Success! Move emotion_model.onnx to your Raspberry Pi.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 5
#       2 import tf2onnx
#       4 # Load your H5 model
# ----> 5 model = tf.keras.models.load_model("emotion_model.hdf5")
#       7 # Convert to ONNX
#       8 spec = (tf.TensorSpec((None, 48, 48, 1), tf.float32, name="input"),)
#
# File c:\Users\nguye\OneDrive\Desktop\uni\Y2_Sem3\jupyter\practice_vscode\my_virtual_env\Lib\site-packages\keras\src\saving\saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath,
# ...
